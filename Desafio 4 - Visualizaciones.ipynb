# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load

# %%
def load_dataframe_from_url(url, encoding = 'utf-8'):
    path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
    df = pd.read_csv(path, encoding = encoding)
    return df


url = "https://drive.google.com/file/d/1Msf9fKLNyQJFmZbPecSe1G23kjkPg-ap/view?usp=sharing"
df = load_dataframe_from_url(url, encoding = 'ISO-8859-1')

# %% [markdown]
# # Punto 2: Histograma de salarios

# %%
fig = plt.figure(figsize=(20,5))
ax1 = plt.subplot2grid(shape=(1,2), loc=(0,0))
ax2 = plt.subplot2grid(shape=(1,2), loc=(0,1))
hist_full = sns.histplot(ax= ax1, data=df.Salary)
hist_full.set_title('Histograma de salarios completo', fontsize = 20)
hist_full.set_xlabel('Salario')
fullhist.set_ylabel('Cantidad')

hist_lower = sns.histplot(ax= ax2, data=df[df.Salary<100000], x= 'Salary')
hist_lower.set_title('Histograma de salarios hasta 100k', fontsize = 20)
hist_lower.set_xlabel('Salario')
hist_lower.set_ylabel('Cantidad')
# Out:
# Text(0, 0.5, 'Cantidad')

# %% [markdown]
# # Punto 3: gráfico violín por género

# %%
df2 = df[df.GenderID.isnull() == False]
fig = plt.figure(figsize=(20,5))
ax1 = plt.subplot2grid(shape=(1,2), loc=(0,0))
ax2 = plt.subplot2grid(shape=(1,2), loc=(0,1))
violin_full = sns.violinplot(ax=ax1, data = df2,y='Salary', x='GenderID')
violin_full.set_title('Gráfico violín de salarios completo', fontsize = 20)
violin_full.set_xticklabels(['Masculino', 'Femenino'])
violin_full.set_ylabel('Salario')
violin_full.set_xlabel('Género')

violin_lower = sns.violinplot(ax=ax2, data = df2[df2.Salary<100000],y='Salary', x='GenderID')
violin_lower.set_title('Gráfico violín de salarios hasta 100k', fontsize = 20)
violin_lower.set_xticklabels(['Masculino', 'Femenino'])
violin_lower.set_ylabel('Salario')
violin_lower.set_xlabel('Género')
# Out:
# Text(0.5, 0, 'Género')

# %% [markdown]
# # Punto 4: Cantidad de contrtaciones por año

# %%
import datetime

datesdf = df[df.DateofHire.isnull() == False].DateofHire.apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y'))
fig = plt.figure(figsize=(20,5))
hires_kde = sns.kdeplot(datesdf, linewidth=3)
hires_kde.set_title('Densidad de contrataciones por año', fontsize = 20)
hires_kde.set_ylabel('Densidad')
hires_kde.set_xlabel('Contrataciones')
# Out:
# Text(0.5, 0, 'Contrataciones')
